# %%
lst = [ 1, 2, 3, 4, 5 ]

# %% [markdown]
# # Dictionaries

# %%
d= {
    "random": "This is the random word.",
    "Pakage": "A pakage is a module which can be added"
}

# %%
type(d)
# Out:
# dict

# %%
d["random"]
# Out:
# 'This is the random word.'

# %%
d['variable'] = "A variable is a box which contains some value."

# %%
d
# Out:
# {'random': 'This is the random word.',
#  'Pakage': 'A pakage is a module which can be added',
#  'variable': 'A variable is a box which contains some value.'}

# %%
d["python"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d["python"]
#
# KeyError: 'python'

# %% [markdown]
# ## Looping over a dictionaries

# %%
for k in d:
    v = d[k]
    print (k, " = ", v)
# Out:
# random  =  This is the random word.
# Pakage  =  A pakage is a module which can be added
# variable  =  A variable is a box which contains some value.

# %%
'python' in d
# Out:
# False

# %%
'random' in d
# Out:
# True

# %%
if 'python' not in d:
    print ("The python is not in d")
else:
    print ("Yes, the python is in the d")
# Out:
# The python is not in d

# %%
if  not 'python' in d:
    print ("The python is not in d")
else:
    print ("Yes, the python is in the d")
# Out:
# The python is not in d

# %%
l = d.items()

# %%
l
# Out:
# dict_items([('random', 'This is the random word.'), ('Pakage', 'A pakage is a module which can be added'), ('variable', 'A variable is a box which contains some value.')])

# %%
I make a dictionarie and apply items func on that and save it in variable l and when i want to retrive l[0] it gives type error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dict_items[0]
#
# NameError: name 'dict_items' is not defined

# %%
l[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l[0]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
type(l)
# Out:
# dict_items

# %%
for k, v in d.items():
    print (k, "=", v)
# Out:
# random = This is the random word.
# Pakage = A pakage is a module which can be added
# variable = A variable is a box which contains some value.

# %%
list(d.items())
# Out:
# [('random', 'This is the random word.'),
#  ('Pakage', 'A pakage is a module which can be added'),
#  ('variable', 'A variable is a box which contains some value.')]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# ('random', 'This is the random word.')

# %%
l[0][0]
# Out:
# 'random'

# %%
type(l[0][0])
# Out:
# str

# %%
autograder_conf = {
    'url': '120.52.432.000.111:8888',
    'username': 'abc',
    'user_pass': '12345'
}

print ( "Connecting to", autograder_conf['url'])
# Out:
# Connecting to 120.52.432.000.111:8888

# %%
v = '1'
int(v)
# Out:
# 1
