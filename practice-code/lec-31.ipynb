# %%
x = 23
y = 32

# %%
print ("x=", x, "y=", y)
# Out:
# x= 23 y= 32

# %%
print(f"x = {x} and y = {y}")
# Out:
# x = 23 and y = 32

# %%
print("x = {} and y = {}".format(x, y))
# Out:
# x = 23 and y = 32

# %%
# This is called padding


l = [1, 2, 34, 456]
for i in l:
    print ("%4d" %i)
# Out:
#    1
#    2
#   34
#  456

# %%
for i in l:
    print ("{:3}".format(i))
# Out:
#   1
#   2
#  34
# 456

# %%
s = "Talha"

# %%
print("={:>10}=".format(s))
# Out:
# =     Talha=
