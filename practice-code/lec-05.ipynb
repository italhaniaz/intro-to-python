# %%
sqrt(36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sqrt(36)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
math.pow(2, 3)
# Out:
# 8.0

# %%
math.sqrt(256)
# Out:
# 16.0

# %%
from math import sqrt

# %%
sqrt(256)
# Out:
# 16.0

# %%
cos(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cos(3)
#
# NameError: name 'cos' is not defined

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/math.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
help(cos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 help(cos)
#
# NameError: name 'cos' is not defined

# %%
help(math.cos)
# Out:
# Help on built-in function cos in module math:
#
# cos(x, /)
#     Return the cosine of x (measured in radians).

# %%
help(sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
help(physics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 help(physics)
#
# NameError: name 'physics' is not defined

# %%
import physics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import physics
#
# ModuleNotFoundError: No module named 'physics'

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
u * 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 u * 2
#
# NameError: name 'u' is not defined

# %%
'a' + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 'a' + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
pow
# Out:
# <function pow(base, exp, mod=None)>

# %%
sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
sqrt = 4

# %%
sqrt
# Out:
# 4

# %%
sqrt(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sqrt(3)
#
# TypeError: 'int' object is not callable

# %%
from math import sqrt

# %%
f = sqrt

# %%
f(36)
# Out:
# 6.0

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
print (f(4))
# Out:
# 2.0

# %%
"Talha"
# Out:
# 'Talha'

# %%
print ("Talha")
# Out:
# Talha

# %%
print ("The sqrt of 4 is:", f(4), "yes correct")
# Out:
# The sqrt of 4 is: 2.0 yes correct

# %%
s = """
This is multi line string which has to be gone 
to the console to be printed by the 
print function
"""

# %%
s
# Out:
# '\nThis is multi line string which has to be gone \nto the console to be printed by the \nprint function\n'

# %%
print (s)
# Out:
# This is multi line string which has to be gone
# to the console to be printed by the
# print function
