# %%
def square(x):
    return x * x

# %%
'a' * 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 'a' * 'a'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
square('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 square('a')
#
# Cell In[1], line 2, in square(x)
#       1 def square(x):
# ----> 2     return x * x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
def sqrt(num, guess=1):
    print ("Finding the squareroot of", num, "starting with guess", guess)

# %%
    sqrt(3, 5)
# Out:
# Finding the squareroot of 3 starting with guess 5

# %%
sqrt(36)
# Out:
# Finding the squareroot of 36 starting with guess 1
